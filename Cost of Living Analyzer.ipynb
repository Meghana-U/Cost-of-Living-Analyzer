# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

import folium
from folium import Circle
from geopy import Nominatim

from sklearn.preprocessing import MinMaxScaler
from IPython.display import display

import warnings
warnings.filterwarnings('ignore')

# %%
city = pd.read_csv('C:/Users/Dell/Desktop/cost-of-living.csv')

# %%
city.head()
# Out:
#                                           Unnamed: 0  \
# 0                       Meal, Inexpensive Restaurant
# 1  Meal for 2 People, Mid-range Restaurant, Three...
# 2     McMeal at McDonalds (or Equivalent Combo Meal)
# 3                  Domestic Beer (0.5 liter draught)
# 4                  Imported Beer (0.33 liter bottle)
#
#    Saint Petersburg, Russia  Istanbul, Turkey  Izmir, Turkey  \
# 0                      7.34              4.58           3.06
# 1                     29.35             15.28          12.22
# 2                      4.40              3.82           3.06
# 3                      2.20              3.06           2.29
# 4                      2.20              3.06           2.75
#
#    Helsinki, Finland  Chisinau, Moldova  Milan, Italy  Cairo, Egypt  \
# 0              12.00               4.67          15.0          3.38
# 1              65.00              20.74          60.0         17.48
# 2               8.00               4.15           8.0          4.51
# 3               6.50               1.04           5.0          1.69
# 4               6.75               1.43           5.0          2.82
#
#    Banja Luka, Bosnia And Herzegovina  Baku, Azerbaijan  ...  Lviv, Ukraine  \
# 0                                3.58              5.27  ...           3.75
# 1                               22.99             23.73  ...          18.76
# 2                                3.58              4.22  ...           3.56
# 3                                1.02              0.84  ...           1.50
# 4                                1.53              2.11  ...           1.50
#
#    Novosibirsk, Russia  Bursa, Turkey  Brussels, Belgium  Jerusalem, Israel  \
# 0                 5.72           3.82               15.0              15.56
# 1                22.01          11.47               60.0              62.24
# 2                 3.67           3.06                8.2              12.97
# 3                 1.10           2.37                4.0               7.26
# 4                 2.20           3.06                4.0               7.26
#
#    Melbourne, Australia  Perth, Australia  Sydney, Australia  \
# 0                 10.22             12.43              11.81
# 1                 49.54             56.55              54.37
# 2                  7.12              7.32               7.15
# 3                  5.57              5.90               4.97
# 4                  5.57              5.59               4.97
#
#    Alexandria, Egypt  Quito, Ecuador
# 0               2.81            3.59
# 1              14.06           31.45
# 2               3.38            5.39
# 3               1.69            1.35
# 4               2.81            2.70
#
# [5 rows x 161 columns]

# %%
locator = Nominatim(user_agent = "myGeocoder")
location = locator.geocode("Saint Petersburg, Russia")

# %%
print('Latitude = {} and Longitude = {}'.format(location.latitude, location.longitude))
# Out:
# Latitude = 59.938732 and Longitude = 30.316229

# %%
city = city.T
city.head()
# Out:
#                                                     0   \
# Unnamed: 0                Meal, Inexpensive Restaurant
# Saint Petersburg, Russia                          7.34
# Istanbul, Turkey                                  4.58
# Izmir, Turkey                                     3.06
# Helsinki, Finland                                   12
#
#                                                                          1   \
# Unnamed: 0                Meal for 2 People, Mid-range Restaurant, Three...
# Saint Petersburg, Russia                                              29.35
# Istanbul, Turkey                                                      15.28
# Izmir, Turkey                                                         12.22
# Helsinki, Finland                                                        65
#
#                                                                       2   \
# Unnamed: 0                McMeal at McDonalds (or Equivalent Combo Meal)
# Saint Petersburg, Russia                                             4.4
# Istanbul, Turkey                                                    3.82
# Izmir, Turkey                                                       3.06
# Helsinki, Finland                                                      8
#
#                                                          3   \
# Unnamed: 0                Domestic Beer (0.5 liter draught)
# Saint Petersburg, Russia                                2.2
# Istanbul, Turkey                                       3.06
# Izmir, Turkey                                          2.29
# Helsinki, Finland                                       6.5
#
#                                                          4   \
# Unnamed: 0                Imported Beer (0.33 liter bottle)
# Saint Petersburg, Russia                                2.2
# Istanbul, Turkey                                       3.06
# Izmir, Turkey                                          2.75
# Helsinki, Finland                                      6.75
#
#                                                       5   \
# Unnamed: 0                Coke/Pepsi (0.33 liter bottle)
# Saint Petersburg, Russia                            0.76
# Istanbul, Turkey                                    0.64
# Izmir, Turkey                                       0.61
# Helsinki, Finland                                   2.66
#
#                                                   6   \
# Unnamed: 0                Water (0.33 liter bottle)
# Saint Petersburg, Russia                        0.53
# Istanbul, Turkey                                0.24
# Izmir, Turkey                                   0.22
# Helsinki, Finland                               1.89
#
#                                                  7   \
# Unnamed: 0                Milk (regular), (1 liter)
# Saint Petersburg, Russia                       0.98
# Istanbul, Turkey                               0.71
# Izmir, Turkey                                  0.65
# Helsinki, Finland                              0.96
#
#                                                         8   \
# Unnamed: 0                Loaf of Fresh White Bread (500g)
# Saint Petersburg, Russia                              0.71
# Istanbul, Turkey                                      0.36
# Izmir, Turkey                                         0.38
# Helsinki, Finland                                     2.27
#
#                                            9   ...                45  \
# Unnamed: 0                Eggs (regular) (12)  ...  Lettuce (1 head)
# Saint Petersburg, Russia                 1.18  ...              0.86
# Istanbul, Turkey                         1.62  ...              0.61
# Izmir, Turkey                            1.51  ...              0.57
# Helsinki, Finland                        2.02  ...               2.3
#
#                                             46                   47  \
# Unnamed: 0                Cappuccino (regular)  Rice (white), (1kg)
# Saint Petersburg, Russia                  1.96                 0.92
# Istanbul, Turkey                          1.84                  1.3
# Izmir, Turkey                             1.56                 1.31
# Helsinki, Finland                         3.87                 2.13
#
#                                     48            49           50  \
# Unnamed: 0                Tomato (1kg)  Banana (1kg)  Onion (1kg)
# Saint Petersburg, Russia          1.91          0.89         0.48
# Istanbul, Turkey                   0.8          1.91         0.62
# Izmir, Turkey                      0.7          1.78         0.58
# Helsinki, Finland                 2.91          1.61         1.25
#
#                                                                          51  \
# Unnamed: 0                Beef Round (1kg) (or Equivalent Back Leg Red M...
# Saint Petersburg, Russia                                               7.18
# Istanbul, Turkey                                                       9.73
# Izmir, Turkey                                                          8.61
# Helsinki, Finland                                                     12.34
#
#                                                                          52  \
# Unnamed: 0                Toyota Corolla 1.6l 97kW Comfort (Or Equivalen...
# Saint Petersburg, Russia                                            19305.3
# Istanbul, Turkey                                                    20874.7
# Izmir, Turkey                                                       20898.8
# Helsinki, Finland                                                   24402.8
#
#                                                                          53  \
# Unnamed: 0                Preschool (or Kindergarten), Full Day, Private...
# Saint Petersburg, Russia                                             411.83
# Istanbul, Turkey                                                     282.94
# Izmir, Turkey                                                        212.18
# Helsinki, Finland                                                     351.6
#
#                                                                         54
# Unnamed: 0                International Primary School, Yearly for 1 Child
# Saint Petersburg, Russia                                           5388.86
# Istanbul, Turkey                                                   6905.43
# Izmir, Turkey                                                      4948.41
# Helsinki, Finland                                                     1641
#
# [5 rows x 55 columns]

# %%
city.rename(columns=city.iloc[0],inplace=True)
city.drop(city.index[0],inplace=True)
city.head()
# Out:
#                          Meal, Inexpensive Restaurant  \
# Saint Petersburg, Russia                         7.34
# Istanbul, Turkey                                 4.58
# Izmir, Turkey                                    3.06
# Helsinki, Finland                                  12
# Chisinau, Moldova                                4.67
#
#                          Meal for 2 People, Mid-range Restaurant, Three-course  \
# Saint Petersburg, Russia                                              29.35
# Istanbul, Turkey                                                      15.28
# Izmir, Turkey                                                         12.22
# Helsinki, Finland                                                        65
# Chisinau, Moldova                                                     20.74
#
#                          McMeal at McDonalds (or Equivalent Combo Meal)  \
# Saint Petersburg, Russia                                            4.4
# Istanbul, Turkey                                                   3.82
# Izmir, Turkey                                                      3.06
# Helsinki, Finland                                                     8
# Chisinau, Moldova                                                  4.15
#
#                          Domestic Beer (0.5 liter draught)  \
# Saint Petersburg, Russia                               2.2
# Istanbul, Turkey                                      3.06
# Izmir, Turkey                                         2.29
# Helsinki, Finland                                      6.5
# Chisinau, Moldova                                     1.04
#
#                          Imported Beer (0.33 liter bottle)  \
# Saint Petersburg, Russia                               2.2
# Istanbul, Turkey                                      3.06
# Izmir, Turkey                                         2.75
# Helsinki, Finland                                     6.75
# Chisinau, Moldova                                     1.43
#
#                          Coke/Pepsi (0.33 liter bottle)  \
# Saint Petersburg, Russia                           0.76
# Istanbul, Turkey                                   0.64
# Izmir, Turkey                                      0.61
# Helsinki, Finland                                  2.66
# Chisinau, Moldova                                  0.64
#
#                          Water (0.33 liter bottle)  Milk (regular), (1 liter)  \
# Saint Petersburg, Russia                       0.53                      0.98
# Istanbul, Turkey                               0.24                      0.71
# Izmir, Turkey                                  0.22                      0.65
# Helsinki, Finland                              1.89                      0.96
# Chisinau, Moldova                              0.44                      0.68
#
#                          Loaf of Fresh White Bread (500g) Eggs (regular) (12)  \
# Saint Petersburg, Russia                             0.71                1.18
# Istanbul, Turkey                                     0.36                1.62
# Izmir, Turkey                                        0.38                1.51
# Helsinki, Finland                                    2.27                2.02
# Chisinau, Moldova                                    0.33                1.11
#
#                           ... Lettuce (1 head) Cappuccino (regular)  \
# Saint Petersburg, Russia  ...             0.86                 1.96
# Istanbul, Turkey          ...             0.61                 1.84
# Izmir, Turkey             ...             0.57                 1.56
# Helsinki, Finland         ...              2.3                 3.87
# Chisinau, Moldova         ...             0.84                 1.25
#
#                          Rice (white), (1kg) Tomato (1kg) Banana (1kg)  \
# Saint Petersburg, Russia                0.92         1.91         0.89
# Istanbul, Turkey                         1.3          0.8         1.91
# Izmir, Turkey                           1.31          0.7         1.78
# Helsinki, Finland                       2.13         2.91         1.61
# Chisinau, Moldova                       0.93         1.56         1.37
#
#                          Onion (1kg)  \
# Saint Petersburg, Russia        0.48
# Istanbul, Turkey                0.62
# Izmir, Turkey                   0.58
# Helsinki, Finland               1.25
# Chisinau, Moldova               0.59
#
#                          Beef Round (1kg) (or Equivalent Back Leg Red Meat)  \
# Saint Petersburg, Russia                                               7.18
# Istanbul, Turkey                                                       9.73
# Izmir, Turkey                                                          8.61
# Helsinki, Finland                                                     12.34
# Chisinau, Moldova                                                      5.37
#
#                          Toyota Corolla 1.6l 97kW Comfort (Or Equivalent New Car)  \
# Saint Petersburg, Russia                                            19305.3
# Istanbul, Turkey                                                    20874.7
# Izmir, Turkey                                                       20898.8
# Helsinki, Finland                                                   24402.8
# Chisinau, Moldova                                                   17238.1
#
#                          Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child  \
# Saint Petersburg, Russia                                             411.83
# Istanbul, Turkey                                                     282.94
# Izmir, Turkey                                                        212.18
# Helsinki, Finland                                                     351.6
# Chisinau, Moldova                                                    210.52
#
#                          International Primary School, Yearly for 1 Child
# Saint Petersburg, Russia                                          5388.86
# Istanbul, Turkey                                                  6905.43
# Izmir, Turkey                                                     4948.41
# Helsinki, Finland                                                    1641
# Chisinau, Moldova                                                  2679.3
#
# [5 rows x 55 columns]

# %%
city = city.reset_index()
city = city.rename(columns = {'index':'Location'})
city.head()
# Out:
#                    Location Meal, Inexpensive Restaurant  \
# 0  Saint Petersburg, Russia                         7.34
# 1          Istanbul, Turkey                         4.58
# 2             Izmir, Turkey                         3.06
# 3         Helsinki, Finland                           12
# 4         Chisinau, Moldova                         4.67
#
#   Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                              29.35
# 1                                              15.28
# 2                                              12.22
# 3                                                 65
# 4                                              20.74
#
#   McMeal at McDonalds (or Equivalent Combo Meal)  \
# 0                                            4.4
# 1                                           3.82
# 2                                           3.06
# 3                                              8
# 4                                           4.15
#
#   Domestic Beer (0.5 liter draught) Imported Beer (0.33 liter bottle)  \
# 0                               2.2                               2.2
# 1                              3.06                              3.06
# 2                              2.29                              2.75
# 3                               6.5                              6.75
# 4                              1.04                              1.43
#
#   Coke/Pepsi (0.33 liter bottle) Water (0.33 liter bottle)   \
# 0                           0.76                       0.53
# 1                           0.64                       0.24
# 2                           0.61                       0.22
# 3                           2.66                       1.89
# 4                           0.64                       0.44
#
#   Milk (regular), (1 liter) Loaf of Fresh White Bread (500g)  ...  \
# 0                      0.98                             0.71  ...
# 1                      0.71                             0.36  ...
# 2                      0.65                             0.38  ...
# 3                      0.96                             2.27  ...
# 4                      0.68                             0.33  ...
#
#   Lettuce (1 head) Cappuccino (regular) Rice (white), (1kg) Tomato (1kg)  \
# 0             0.86                 1.96                0.92         1.91
# 1             0.61                 1.84                 1.3          0.8
# 2             0.57                 1.56                1.31          0.7
# 3              2.3                 3.87                2.13         2.91
# 4             0.84                 1.25                0.93         1.56
#
#   Banana (1kg) Onion (1kg) Beef Round (1kg) (or Equivalent Back Leg Red Meat)  \
# 0         0.89        0.48                                               7.18
# 1         1.91        0.62                                               9.73
# 2         1.78        0.58                                               8.61
# 3         1.61        1.25                                              12.34
# 4         1.37        0.59                                               5.37
#
#   Toyota Corolla 1.6l 97kW Comfort (Or Equivalent New Car)  \
# 0                                            19305.3
# 1                                            20874.7
# 2                                            20898.8
# 3                                            24402.8
# 4                                            17238.1
#
#   Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child  \
# 0                                             411.83
# 1                                             282.94
# 2                                             212.18
# 3                                              351.6
# 4                                             210.52
#
#   International Primary School, Yearly for 1 Child
# 0                                          5388.86
# 1                                          6905.43
# 2                                          4948.41
# 3                                             1641
# 4                                           2679.3
#
# [5 rows x 56 columns]

# %%
city.columns
# Out:
# Index(['Location', 'Meal, Inexpensive Restaurant',
#        'Meal for 2 People, Mid-range Restaurant, Three-course',
#        'McMeal at McDonalds (or Equivalent Combo Meal)',
#        'Domestic Beer (0.5 liter draught)',
#        'Imported Beer (0.33 liter bottle)', 'Coke/Pepsi (0.33 liter bottle)',
#        'Water (0.33 liter bottle) ', 'Milk (regular), (1 liter)',
#        'Loaf of Fresh White Bread (500g)', 'Eggs (regular) (12)',
#        'Local Cheese (1kg)', 'Water (1.5 liter bottle)',
#        'Bottle of Wine (Mid-Range)', 'Domestic Beer (0.5 liter bottle)',
#        'Imported Beer (0.33 liter bottle)', 'Cigarettes 20 Pack (Marlboro)',
#        'One-way Ticket (Local Transport)',
#        'Chicken Breasts (Boneless, Skinless), (1kg)',
#        'Monthly Pass (Regular Price)', 'Gasoline (1 liter)', 'Volkswagen Golf',
#        'Apartment (1 bedroom) in City Centre',
#        'Apartment (1 bedroom) Outside of Centre',
#        'Apartment (3 bedrooms) in City Centre',
#        'Apartment (3 bedrooms) Outside of Centre',
#        'Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment',
#        '1 min. of Prepaid Mobile Tariff Local (No Discounts or Plans)',
#        'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)',
#        'Fitness Club, Monthly Fee for 1 Adult',
#        'Tennis Court Rent (1 Hour on Weekend)',
#        'Cinema, International Release, 1 Seat',
#        '1 Pair of Jeans (Levis 501 Or Similar)',
#        '1 Summer Dress in a Chain Store (Zara, H&M, ...)',
#        '1 Pair of Nike Running Shoes (Mid-Range)',
#        '1 Pair of Men Leather Business Shoes',
#        'Price per Square Meter to Buy Apartment in City Centre',
#        'Price per Square Meter to Buy Apartment Outside of Centre',
#        'Average Monthly Net Salary (After Tax)',
#        'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate',
#        'Taxi Start (Normal Tariff)', 'Taxi 1km (Normal Tariff)',
#        'Taxi 1hour Waiting (Normal Tariff)', 'Apples (1kg)', 'Oranges (1kg)',
#        'Potato (1kg)', 'Lettuce (1 head)', 'Cappuccino (regular)',
#        'Rice (white), (1kg)', 'Tomato (1kg)', 'Banana (1kg)', 'Onion (1kg)',
#        'Beef Round (1kg) (or Equivalent Back Leg Red Meat)',
#        'Toyota Corolla 1.6l 97kW Comfort (Or Equivalent New Car)',
#        'Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child',
#        'International Primary School, Yearly for 1 Child'],
#       dtype='object')

# %%
from geopy.extra.rate_limiter import RateLimiter
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)
city['location'] = city['Location'].apply(geocode)
city['point'] = city['location'].apply(lambda loc: tuple(loc.point) if loc else None)
city[['latitude','longitude','altitude']] = pd.DataFrame(city['point'].tolist(), index=city.index)
city.head()
# Out:
#                    Location Meal, Inexpensive Restaurant  \
# 0  Saint Petersburg, Russia                         7.34
# 1          Istanbul, Turkey                         4.58
# 2             Izmir, Turkey                         3.06
# 3         Helsinki, Finland                           12
# 4         Chisinau, Moldova                         4.67
#
#   Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                              29.35
# 1                                              15.28
# 2                                              12.22
# 3                                                 65
# 4                                              20.74
#
#   McMeal at McDonalds (or Equivalent Combo Meal)  \
# 0                                            4.4
# 1                                           3.82
# 2                                           3.06
# 3                                              8
# 4                                           4.15
#
#   Domestic Beer (0.5 liter draught) Imported Beer (0.33 liter bottle)  \
# 0                               2.2                               2.2
# 1                              3.06                              3.06
# 2                              2.29                              2.75
# 3                               6.5                              6.75
# 4                              1.04                              1.43
#
#   Coke/Pepsi (0.33 liter bottle) Water (0.33 liter bottle)   \
# 0                           0.76                       0.53
# 1                           0.64                       0.24
# 2                           0.61                       0.22
# 3                           2.66                       1.89
# 4                           0.64                       0.44
#
#   Milk (regular), (1 liter) Loaf of Fresh White Bread (500g)  ... Onion (1kg)  \
# 0                      0.98                             0.71  ...        0.48
# 1                      0.71                             0.36  ...        0.62
# 2                      0.65                             0.38  ...        0.58
# 3                      0.96                             2.27  ...        1.25
# 4                      0.68                             0.33  ...        0.59
#
#   Beef Round (1kg) (or Equivalent Back Leg Red Meat)  \
# 0                                               7.18
# 1                                               9.73
# 2                                               8.61
# 3                                              12.34
# 4                                               5.37
#
#   Toyota Corolla 1.6l 97kW Comfort (Or Equivalent New Car)  \
# 0                                            19305.3
# 1                                            20874.7
# 2                                            20898.8
# 3                                            24402.8
# 4                                            17238.1
#
#   Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child  \
# 0                                             411.83
# 1                                             282.94
# 2                                             212.18
# 3                                              351.6
# 4                                             210.52
#
#   International Primary School, Yearly for 1 Child  \
# 0                                          5388.86
# 1                                          6905.43
# 2                                          4948.41
# 3                                             1641
# 4                                           2679.3
#
#                                             location  \
# 0  (Санкт-Петербург, Северо-Западный федеральный ...
# 1  (İstanbul, Fatih, İstanbul, Marmara Bölgesi, 3...
# 2  (İzmir, Konak, İzmir, Ege Bölgesi, UNKNWON, Tü...
# 3  (Helsinki, Helsingin seutukunta, Uusimaa, Etel...
# 4  (Chișinău, Sectorul Buiucani, Municipiul Chiși...
#
#                            point   latitude  longitude altitude
# 0    (59.938732, 30.316229, 0.0)  59.938732  30.316229      0.0
# 1  (41.0096334, 28.9651646, 0.0)  41.009633  28.965165      0.0
# 2  (38.4147331, 27.1434119, 0.0)  38.414733  27.143412      0.0
# 3  (60.1674881, 24.9427473, 0.0)  60.167488  24.942747      0.0
# 4  (47.0245117, 28.8322923, 0.0)  47.024512  28.832292      0.0
#
# [5 rows x 61 columns]

# %%
city = city.drop(['location','point','altitude'],axis=1)
city.columns
# Out:
# Index(['Location', 'Meal, Inexpensive Restaurant',
#        'Meal for 2 People, Mid-range Restaurant, Three-course',
#        'McMeal at McDonalds (or Equivalent Combo Meal)',
#        'Domestic Beer (0.5 liter draught)',
#        'Imported Beer (0.33 liter bottle)', 'Coke/Pepsi (0.33 liter bottle)',
#        'Water (0.33 liter bottle) ', 'Milk (regular), (1 liter)',
#        'Loaf of Fresh White Bread (500g)', 'Eggs (regular) (12)',
#        'Local Cheese (1kg)', 'Water (1.5 liter bottle)',
#        'Bottle of Wine (Mid-Range)', 'Domestic Beer (0.5 liter bottle)',
#        'Imported Beer (0.33 liter bottle)', 'Cigarettes 20 Pack (Marlboro)',
#        'One-way Ticket (Local Transport)',
#        'Chicken Breasts (Boneless, Skinless), (1kg)',
#        'Monthly Pass (Regular Price)', 'Gasoline (1 liter)', 'Volkswagen Golf',
#        'Apartment (1 bedroom) in City Centre',
#        'Apartment (1 bedroom) Outside of Centre',
#        'Apartment (3 bedrooms) in City Centre',
#        'Apartment (3 bedrooms) Outside of Centre',
#        'Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment',
#        '1 min. of Prepaid Mobile Tariff Local (No Discounts or Plans)',
#        'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)',
#        'Fitness Club, Monthly Fee for 1 Adult',
#        'Tennis Court Rent (1 Hour on Weekend)',
#        'Cinema, International Release, 1 Seat',
#        '1 Pair of Jeans (Levis 501 Or Similar)',
#        '1 Summer Dress in a Chain Store (Zara, H&M, ...)',
#        '1 Pair of Nike Running Shoes (Mid-Range)',
#        '1 Pair of Men Leather Business Shoes',
#        'Price per Square Meter to Buy Apartment in City Centre',
#        'Price per Square Meter to Buy Apartment Outside of Centre',
#        'Average Monthly Net Salary (After Tax)',
#        'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate',
#        'Taxi Start (Normal Tariff)', 'Taxi 1km (Normal Tariff)',
#        'Taxi 1hour Waiting (Normal Tariff)', 'Apples (1kg)', 'Oranges (1kg)',
#        'Potato (1kg)', 'Lettuce (1 head)', 'Cappuccino (regular)',
#        'Rice (white), (1kg)', 'Tomato (1kg)', 'Banana (1kg)', 'Onion (1kg)',
#        'Beef Round (1kg) (or Equivalent Back Leg Red Meat)',
#        'Toyota Corolla 1.6l 97kW Comfort (Or Equivalent New Car)',
#        'Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child',
#        'International Primary School, Yearly for 1 Child', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
# Aggregating Features
def food(city):
    return int(round((city[['Meal, Inexpensive Restaurant',
       'Meal for 2 People, Mid-range Restaurant, Three-course',
       'McMeal at McDonalds (or Equivalent Combo Meal)',
       'Domestic Beer (0.5 liter draught)',
       'Imported Beer (0.33 liter bottle)', 'Coke/Pepsi (0.33 liter bottle)',
       'Water (0.33 liter bottle) ', 'Milk (regular), (1 liter)',
       'Loaf of Fresh White Bread (500g)', 'Eggs (regular) (12)',
       'Local Cheese (1kg)', 'Water (1.5 liter bottle)',
       'Bottle of Wine (Mid-Range)', 'Domestic Beer (0.5 liter bottle)',
       'Imported Beer (0.33 liter bottle)', 'Cigarettes 20 Pack (Marlboro)',
        'Chicken Breasts (Boneless, Skinless), (1kg)','Apples (1kg)', 'Oranges (1kg)',
       'Potato (1kg)', 'Lettuce (1 head)', 'Cappuccino (regular)',
       'Rice (white), (1kg)', 'Tomato (1kg)', 'Banana (1kg)', 'Onion (1kg)',
       'Beef Round (1kg) (or Equivalent Back Leg Red Meat)',]].mean()).mean()))

def travel(city):
    return int(round((city[['One-way Ticket (Local Transport)','Monthly Pass (Regular Price)',
                            'Gasoline (1 liter)','Taxi Start (Normal Tariff)', 'Taxi 1km (Normal Tariff)',
                            'Taxi 1hour Waiting (Normal Tariff)',]].mean()).mean()))

def living(city):
    return int(round((city[['Volkswagen Golf',
       'Apartment (1 bedroom) in City Centre',
       'Apartment (1 bedroom) Outside of Centre',
       'Apartment (3 bedrooms) in City Centre',
       'Apartment (3 bedrooms) Outside of Centre',
       'Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment',
       'Price per Square Meter to Buy Apartment in City Centre',
       'Price per Square Meter to Buy Apartment Outside of Centre',
       'Toyota Corolla 1.6l 97kW Comfort (Or Equivalent New Car)',]].mean()).mean()))

def lifestyle(city):
    return int(round((city[['1 min. of Prepaid Mobile Tariff Local (No Discounts or Plans)',
       'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)',
       'Fitness Club, Monthly Fee for 1 Adult',
       'Tennis Court Rent (1 Hour on Weekend)',
       'Cinema, International Release, 1 Seat',
       '1 Pair of Jeans (Levis 501 Or Similar)',
       '1 Summer Dress in a Chain Store (Zara, H&M, ...)',
       '1 Pair of Nike Running Shoes (Mid-Range)',
       '1 Pair of Men Leather Business Shoes',]].mean()).mean()))

def education(city):
    return int(round((city[['Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child',
       'International Primary School, Yearly for 1 Child',]].mean()).mean()))

def income(city):
    return int(round((city[['Average Monthly Net Salary (After Tax)',
       'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate',]].mean()).mean()))

# %%
city['Food'] = city.apply(food,axis=1)
city['Travel'] = city.apply(travel,axis=1)
city['Living'] = city.apply(living,axis=1)
city['Lifestyle'] = city.apply(lifestyle,axis=1)
city['Education'] = city.apply(education,axis=1)
city['Income'] = city.apply(income,axis=1)

# %%
city['Location'].str.split(', ')[0]
# Out:
# ['Saint Petersburg', 'Russia']

# %%
# split location to fetch country names
city['country'] = city['Location'].str.split(', ')
city['Country'] = city['country'].apply(lambda x: x[1])
city['Country'].value_counts()
# Out:
# India        11
# Canada        8
# Poland        6
# Australia     5
# Romania       5
#              ..
# Estonia       1
# Austria       1
# Peru          1
# Argentina     1
# IL            1
# Name: Country, Length: 90, dtype: int64

# %%
city[['Country','Food','Travel',
      'Living','Lifestyle','Education','Income']].groupby(['Country']).agg('mean').style.background_gradient(cmap='Wistia')
# Out:
# <style  type="text/css" >
# #T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row0_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row4_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row8_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row13_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row13_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row24_col3,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row30_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row36_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row38_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row39_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row53_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row57_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row59_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row69_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row73_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row73_col4,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row78_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row79_col3,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row80_col3,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row84_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row85_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row86_col3{
#             background-color:  #ffc706;
#             color:  #000000;
#         }#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row0_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row13_col5,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row53_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row56_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row69_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row84_col5{
#             background-color:  #ffcc09;
#             color:  #000000;
#         }#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row0_col2,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row18_col2,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row19_col2,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row53_col2,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row62_col4,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row72_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row83_col2,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row86_col4{
#             background-color:  #f4f242;
#             color:  #000000;
#         }#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row0_col3,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row5_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row6_col3,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row7_col3,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row19_col3,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row28_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row37_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row50_col3,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row60_col3,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row78_col1{
#             background-color:  #ffd50e;
#             color:  #000000;
#         }#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row0_col4,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row85_col2{
#             background-color:  #ffd30d;
#             color:  #000000;
#         }#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row0_col5,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row8_col3,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row12_col3,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row20_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row25_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row28_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row32_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row39_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row73_col3,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row85_col3{
#             background-color:  #ffba00;
#             color:  #000000;
#         }#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row1_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row1_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row2_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row3_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row6_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row7_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row9_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row10_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row11_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row19_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row31_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row40_col4,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row42_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row43_col5,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row47_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row48_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row48_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row49_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row51_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row52_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row52_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row60_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row60_col2,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row61_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row62_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row63_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row66_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row70_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row72_col2,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row75_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row88_col0{
#             background-color:  #f0f550;
#             color:  #000000;
#         }#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row1_col2,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row6_col2,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row18_col4,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row61_col2,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row66_col2,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row68_col4,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row80_col5{
#             background-color:  #edf759;
#             color:  #000000;
#         }#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row1_col3,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row9_col3,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row27_col3,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row28_col4,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row31_col3,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row35_col3,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row58_col4{
#             background-color:  #ffe015;
#             color:  #000000;
#         }#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row1_col4,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row7_col5,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row34_col3,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row61_col5,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row68_col5,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row82_col5{
#             background-color:  #e9fb69;
#             color:  #000000;
#         }#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row1_col5,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row42_col5,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row81_col4{
#             background-color:  #e7fd71;
#             color:  #000000;
#         }#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row2_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row3_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row7_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row23_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row35_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row50_col4,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row62_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row68_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row81_col1,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row87_col1{
#             background-color:  #eafa65;
#             color:  #000000;
#         }#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row2_col2,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row62_col2{
#             background-color:  #eff654;
#             color:  #000000;
#         }#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row2_col3,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row10_col3,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row29_col0,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row70_col3{
#             background-color:  #ffe317;
#             color:  #000000;
#         }#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row2_col4,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row11_col5{
#             background-color:  #ebf960;
#             color:  #000000;
#         }#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row2_col5,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row14_col2,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row22_col5,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row42_col2,#T_5dd0d79e_3d54_11eb_85a2_a87eeac12176row55_col3{
#             background-color:  #eafa63;
#             color:  #000000;

# %%
# Top 5 Most Expensive Countries 
plt.rcParams['figure.figsize'] = (17,7)

plt.subplot(2,3,1)
x = city[['Country','Food']].sort_values(by = 'Food',ascending=False).head(5)
sns.barplot(x['Country'],x['Food'],palette='viridis')
plt.xticks(rotation=5)
plt.xlabel(' ')

plt.subplot(2,3,2)
x = city[['Country','Travel']].sort_values(by = 'Travel',ascending=False).head(5)
sns.barplot(x['Country'],x['Travel'],palette='viridis')
plt.xticks(rotation=16)
plt.xlabel(' ')

plt.subplot(2,3,3)
x = city[['Country','Living']].sort_values(by = 'Living',ascending=False).head(5)
sns.barplot(x['Country'],x['Living'],palette='viridis')
plt.xticks(rotation=15)
plt.xlabel(' ')

plt.subplot(2,3,4)
x = city[['Country','Lifestyle']].sort_values(by = 'Lifestyle',ascending=False).head(5)
sns.barplot(x['Country'],x['Lifestyle'],palette='viridis')
plt.xticks(rotation=15)
plt.xlabel(' ')

plt.subplot(2,3,5)
x = city[['Country','Education']].sort_values(by = 'Education',ascending=False).head(5)
sns.barplot(x['Country'],x['Education'],palette='viridis')
plt.xticks(rotation=5)
plt.xlabel(' ')

plt.subplot(2,3,6)
x = city[['Country','Income']].sort_values(by = 'Income',ascending=False).head(5)
sns.barplot(x['Country'],x['Income'],palette='viridis')
plt.xticks(rotation=5)
plt.xlabel(' ')

plt.suptitle('Most Expensive Countries (Expenses in Euro)',fontsize=15)
plt.show()

# %%
# Top 5 Least Expensive Countries 
plt.rcParams['figure.figsize'] = (17,7)

plt.subplot(2,3,1)
x = city[['Country','Food']].sort_values(by = 'Food',ascending=True).head(5)
sns.barplot(x['Country'],x['Food'],palette='Reds')
plt.xticks(rotation=8)
plt.xlabel(' ')

plt.subplot(2,3,2)
x = city[['Country','Travel']].sort_values(by = 'Travel',ascending=True).head(10)
sns.barplot(x['Country'],x['Travel'],palette='Reds')
plt.xticks(rotation=15)
plt.xlabel(' ')

plt.subplot(2,3,3)
x = city[['Country','Living']].sort_values(by = 'Living',ascending=True).head(5)
sns.barplot(x['Country'],x['Living'],palette='Reds')
plt.xticks(rotation=15)
plt.xlabel(' ')

plt.subplot(2,3,4)
x = city[['Country','Lifestyle']].sort_values(by = 'Lifestyle',ascending=True).head(5)
sns.barplot(x['Country'],x['Lifestyle'],palette='Reds')
plt.xticks(rotation=15)
plt.xlabel(' ')

plt.subplot(2,3,5)
x = city[['Country','Education']].sort_values(by = 'Education',ascending=True).head(5)
sns.barplot(x['Country'],x['Education'],palette='Reds')
plt.xticks(rotation=10)
plt.xlabel(' ')

plt.subplot(2,3,6)
x = city[['Country','Income']].sort_values(by = 'Income',ascending=True).head(5)
sns.barplot(x['Country'],x['Income'],palette='Reds')
plt.xticks(rotation=10)
plt.xlabel(' ')

plt.suptitle('Least Expensive Countries (Expenses in Euro)',fontsize=15)
plt.show()

# %%
city.describe()
# Out:
#          latitude   longitude        Food      Travel        Living  \
# count  160.000000  160.000000  160.000000  160.000000    160.000000
# mean    32.640497   14.651266    4.331250   10.231250   5622.043750
# std     24.340665   67.854594    1.855544    7.575384   1916.624888
# min    -37.814218 -123.364953    2.000000    1.000000   2609.000000
# 25%     25.065637   -1.208147    3.000000    5.000000   4480.500000
# 50%     41.079542   20.731811    4.000000    7.000000   5080.500000
# 75%     48.940584   46.059256    6.000000   16.000000   6502.750000
# max     64.145981  174.763180   11.000000   37.000000  19937.000000
#
#         Lifestyle     Education       Income
# count  160.000000    160.000000   160.000000
# mean    37.231250   4243.525000   726.937500
# std      9.181073   3156.485586   627.321046
# min     17.000000    417.000000    90.000000
# 25%     32.000000   1954.500000   241.500000
# 50%     37.000000   3414.000000   434.000000
# 75%     43.000000   5606.750000  1188.250000
# max     68.000000  18274.000000  3268.000000

# %%
top_range = (city.describe().loc['min',:]/city.describe().loc['max',:]).sort_values().index[2:]
list(top_range)
# Out:
# ['Education', 'Travel', 'Income', 'Living', 'Food', 'Lifestyle']

# %%
def color_producer(val):
    if val<=city[item].quantile(.25):
        return 'forestgreen'
    elif val<=city[item].quantile(.50):
        return 'goldenrod'
    elif val<=city[item].quantile(.75):
        return 'darkred'
    else:
        return 'red'

# %%
map = folium.Map(location=[city['latitude'].mean(),
                city['longitude'].mean()],
                tiles = 'Stamen Terrain',zoom_start=2)
item = top_range[0]

# Bubble map
for i in range(0,len(city)):
    Circle(
    location=[city.iloc[i]['latitude'],city.iloc[i]['longitude']],
    radius = 120000,
    color = color_producer(city.iloc[i][item])).add_to(map)
    
print('Price of :',item)
map
# Out:
# Price of : Education
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[city['latitude'].mean(),
                city['longitude'].mean()],
                tiles = 'Stamen Toner',zoom_start=2)
item = top_range[1]

# Bubble map
for i in range(0,len(city)):
    Circle(
    location=[city.iloc[i]['latitude'],city.iloc[i]['longitude']],
    radius = 120000,
    color = color_producer(city.iloc[i][item])).add_to(map)
    
print('Price of :',item)
map
# Out:
# Price of : Travel
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[city['latitude'].mean(),
                city['longitude'].mean()],
                tiles = 'CartoDB dark_matter',zoom_start=2)
item = top_range[2]

# Bubble map
for i in range(0,len(city)):
    Circle(
    location=[city.iloc[i]['latitude'],city.iloc[i]['longitude']],
    radius = 120000,
    color = color_producer(city.iloc[i][item])).add_to(map)
    
print('Price of :',item)
map
# Out:
# Price of : Income
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[city['latitude'].mean(),
                city['longitude'].mean()],
                tiles = 'Stamen Watercolor',zoom_start=2)
item = top_range[3]

# Bubble map
for i in range(0,len(city)):
    Circle(
    location=[city.iloc[i]['latitude'],city.iloc[i]['longitude']],
    radius = 120000,
    color = color_producer(city.iloc[i][item])).add_to(map)
    
print('Price of :',item)
map
# Out:
# Price of : Living
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[city['latitude'].mean(),
                city['longitude'].mean()],
                tiles = 'Open Street Map',zoom_start=2)
item = top_range[4]

# Bubble map
for i in range(0,len(city)):
    Circle(
    location=[city.iloc[i]['latitude'],city.iloc[i]['longitude']],
    radius = 120000,
    color = color_producer(city.iloc[i][item])).add_to(map)
    
print('Price of :',item)
map
# Out:
# Price of : Food
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[city['latitude'].mean(),
                city['longitude'].mean()],
                tiles = 'CartoDB Positron',zoom_start=2)
item = top_range[5]

# Bubble map
for i in range(0,len(city)):
    Circle(
    location=[city.iloc[i]['latitude'],city.iloc[i]['longitude']],
    radius = 120000,
    color = color_producer(city.iloc[i][item])).add_to(map)
    
print('Price of :',item)
map
# Out:
# Price of : Lifestyle
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plt.rcParams['figure.figsize'] = (15, 5)
plt.style.use('fivethirtyeight')

sns.heatmap(city[['Food','Travel','Living','Lifestyle','Education','Income']].corr(),
            cmap = 'magma', 
            annot = True, linecolor='black', linewidths = 10)
plt.title('Correlation between Major Life Style Factors', fontsize = 20)
plt.show()

# %%
city[city['Country'] == 'Germany']
# Out:
#               Location Meal, Inexpensive Restaurant  \
# 36     Berlin, Germany                          8.5
# 51  Frankfurt, Germany                           10
# 55    Hamburg, Germany                           11
# 67     Munich, Germany                           12
#
#    Meal for 2 People, Mid-range Restaurant, Three-course  \
# 36                                                 40
# 51                                                 50
# 55                                                 50
# 67                                                 60
#
#    McMeal at McDonalds (or Equivalent Combo Meal)  \
# 36                                              7
# 51                                              8
# 55                                              8
# 67                                              8
#
#    Domestic Beer (0.5 liter draught) Imported Beer (0.33 liter bottle)  \
# 36                               3.5                               3.1
# 51                                 4                               3.5
# 55                                 4                               3.5
# 67                               3.8                               3.9
#
#    Coke/Pepsi (0.33 liter bottle) Water (0.33 liter bottle)   \
# 36                           2.02                       1.73
# 51                           2.39                        2.1
# 55                            2.6                       2.09
# 67                           2.73                       2.44
#
#    Milk (regular), (1 liter) Loaf of Fresh White Bread (500g)  ...   latitude  \
# 36                       0.8                             1.34  ...  52.517037
# 51                      0.72                             1.27  ...  50.110644
# 55                      0.85                             1.58  ...  53.550341
# 67                      0.86                             1.56  ...  48.137108
#
#     longitude Food Travel Living Lifestyle Education Income  \
# 36  13.388860    5     20   5978        43      3503   1146
# 51   8.682092    5     22   6871        45      6502   1310
# 55  10.000654    5     21   5940        47      7085   1267
# 67  11.575382    6     17   7445        47      5867   1315
#
#                  country  Country
# 36     [Berlin, Germany]  Germany
# 51  [Frankfurt, Germany]  Germany
# 55    [Hamburg, Germany]  Germany
# 67     [Munich, Germany]  Germany
#
# [4 rows x 66 columns]

# %%
# United Kingdom vs Indian Cost of Living Analysis
city[(city['Country'] == 'Germany') | (city['Country'] == 'India')][['Location','Food','Travel',
       'Living','Lifestyle','Education','Income']].set_index('Location').style.background_gradient(cmap='copper')
# Out:
# <style  type="text/css" >
# #T_89f3bc52_3d54_11eb_98d0_a87eeac12176row0_col0,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row1_col0,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row2_col0{
#             background-color:  #ed9660;
#             color:  #000000;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row0_col1{
#             background-color:  #ffb473;
#             color:  #000000;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row0_col2{
#             background-color:  #c27b4e;
#             color:  #000000;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row0_col3{
#             background-color:  #ffad6e;
#             color:  #000000;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row0_col4{
#             background-color:  #8d5939;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row0_col5,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row1_col2{
#             background-color:  #ffaa6c;
#             color:  #000000;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row1_col1,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row2_col3,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row2_col4,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row3_col0,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row3_col2,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row3_col3,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row3_col5{
#             background-color:  #ffc77f;
#             color:  #000000;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row1_col3{
#             background-color:  #ffba76;
#             color:  #000000;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row1_col4{
#             background-color:  #ffb674;
#             color:  #000000;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row1_col5{
#             background-color:  #ffc67e;
#             color:  #000000;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row2_col1{
#             background-color:  #ffbe79;
#             color:  #000000;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row2_col2{
#             background-color:  #be784d;
#             color:  #000000;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row2_col5{
#             background-color:  #ffbf7a;
#             color:  #000000;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row3_col1{
#             background-color:  #f19861;
#             color:  #000000;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row3_col4{
#             background-color:  #ffa267;
#             color:  #000000;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row4_col0,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row10_col0,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row13_col0{
#             background-color:  #4f3220;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row4_col1,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row4_col4,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row11_col4{
#             background-color:  #0f0906;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row4_col2{
#             background-color:  #140c08;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row4_col3,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row5_col3{
#             background-color:  #342115;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row4_col5,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row6_col3,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row11_col3,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row12_col3{
#             background-color:  #0a0604;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row5_col0,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row6_col0,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row6_col1,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row6_col5,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row7_col0,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row8_col0,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row8_col3,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row9_col0,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row11_col0,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row12_col0,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row12_col1,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row12_col2,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row12_col4,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row13_col1,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row14_col0{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row5_col1,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row7_col1,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row8_col1,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row9_col1,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row10_col1,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row11_col1,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row14_col1,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row14_col5{
#             background-color:  #1e130c;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row5_col2{
#             background-color:  #050302;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row5_col4{
#             background-color:  #1a100a;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row5_col5,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row7_col3,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row14_col2{
#             background-color:  #1f140c;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row6_col2,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row8_col4,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row14_col4{
#             background-color:  #090503;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row6_col4{
#             background-color:  #020201;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row7_col2,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row9_col3,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row13_col3,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row14_col3{
#             background-color:  #2a1b11;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row7_col4{
#             background-color:  #21150d;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row7_col5,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row10_col2{
#             background-color:  #25170f;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row8_col2{
#             background-color:  #20140d;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row8_col5,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row9_col4{
#             background-color:  #0e0905;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row9_col2,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row9_col5,#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row11_col2{
#             background-color:  #160e09;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row10_col3{
#             background-color:  #543522;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row10_col4{
#             background-color:  #23160e;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row10_col5{
#             background-color:  #4b301e;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row11_col5{
#             background-color:  #130c07;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row12_col5{
#             background-color:  #010100;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row13_col2{
#             background-color:  #593824;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row13_col4{
#             background-color:  #170f09;
#             color:  #f1f1f1;
#         }#T_89f3bc52_3d54_11eb_98d0_a87eeac12176row13_col5{
#             background-color:  #19100a;
#             color:  #f1f1f1;
#         }</style><table id="T_89f3bc52_3d54_11eb_98d0_a87eeac12176" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Food</th>        <th class="col_heading level0 col1" >Travel</th>        <th class="col_heading level0 col2" >Living</th>        <th cla

# %%
# Plot to compare Indian cities
city['City'] = city['Location'].str.split(', ')
city['City'] = city['City'].apply(lambda x: x[0])


x = city[city['Country']=='India']

plt.rcParams['figure.figsize'] = (15,15)
plt.subplot(3,2,1)
sns.barplot(y=x['City'],x=x['Food'],palette = 'spring')
plt.ylabel(' ')

plt.subplot(3,2,2)
sns.barplot(y=x['City'],x=x['Travel'],palette = 'spring')
plt.ylabel(' ')

plt.subplot(3,2,3)
sns.barplot(y=x['City'],x=x['Living'],palette = 'spring')
plt.ylabel(' ')

plt.subplot(3,2,4)
sns.barplot(y=x['City'],x=x['Lifestyle'],palette = 'spring')
plt.ylabel(' ')

plt.subplot(3,2,5)
sns.barplot(y=x['City'],x=x['Education'],palette = 'spring')
plt.ylabel(' ')

plt.subplot(3,2,6)
sns.barplot(y=x['City'],x=x['Income'],palette = 'spring')

plt.suptitle('Comparision of Indian Cities',fontsize = 15)
plt.show()

# %%
x = city[['Food','Travel','Living','Lifestyle','Education','Income']]
mm = MinMaxScaler()
data = mm.fit_transform(x)
data = pd.DataFrame(data)
data.columns = x.columns
data.head()
# Out:
#        Food    Travel    Living  Lifestyle  Education    Income
# 0  0.111111  0.194444  0.139139   0.411765   0.139049  0.074890
# 1  0.111111  0.138889  0.161588   0.176471   0.177913  0.043424
# 2  0.000000  0.111111  0.155125   0.098039   0.121129  0.036816
# 3  0.555556  0.527778  0.252539   0.568627   0.032424  0.346759
# 4  0.000000  0.027778  0.082583   0.372549   0.057568  0.018250

# %%
data['Total Score'] = (data['Food']+data['Travel']+data['Living']+data['Lifestyle']+data['Education']+data['Income'])/6
cities = city[['City','Country']]
data = pd.concat([data,cities],axis=1)
data[['Country','City','Total Score']].sort_values(by = 'Total Score', ascending = False).head(10)
# Out:
#             Country           City  Total Score
# 144     Switzerland         Zurich     0.793643
# 78               NY       New York     0.681004
# 100              CA  San Francisco     0.655331
# 128         Iceland      Reykjavik     0.583031
# 39        Singapore      Singapore     0.561809
# 70   United Kingdom         London     0.561487
# 50           Norway           Oslo     0.544841
# 102              WA        Seattle     0.537025
# 47               MA         Boston     0.520049
# 71               CA    Los Angeles     0.484826

# %%
# Most Expensive Places to live
data[['Country','City','Total Score']].sort_values(by='Total Score',ascending=False).head(5)

# Cheapest Places to live
data[['Country','City','Total Score']].sort_values(by='Total Score',ascending=True).head(5)
# Out:
#     Country       City  Total Score
# 123   India    Kolkata     0.018691
# 106   India  Ahmedabad     0.019820
# 112   India    Chennai     0.032235
# 118   India  Hyderabad     0.036584
# 114   India      Delhi     0.047149

# %%
# Renaming Columns that are most common in day to day life
x = city[['Country','City','Milk (regular), (1 liter)',
         'Eggs (regular) (12)', 'Loaf of Fresh White Bread (500g)',
         'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)',
         'Taxi 1km (Normal Tariff)',
         'Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment',]]

x = x.rename(columns = {'Milk (regular), (1 liter)' : 'Milk',
                        'Eggs (regular) (12)' : 'Eggs',
                        'Loaf of Fresh White Bread (500g)' : 'Bread',
                        'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)' : 'Internet',
                        'Taxi 1km (Normal Tariff)' : 'Taxi Travel',
                        'Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment' : 'Electricity and Water'})
x.head()
# Out:
#    Country              City  Milk  Eggs Bread Internet Taxi Travel  \
# 0   Russia  Saint Petersburg  0.98  1.18  0.71     6.96        0.26
# 1   Turkey          Istanbul  0.71  1.62  0.36     14.2        0.47
# 2   Turkey             Izmir  0.65  1.51  0.38    12.89        0.57
# 3  Finland          Helsinki  0.96  2.02  2.27    22.31           1
# 4  Moldova          Chisinau  0.68  1.11  0.33     8.58        0.18
#
#   Electricity and Water
# 0                102.17
# 1                 59.33
# 2                 51.07
# 3                 82.66
# 4                113.46

# %%
x[['Milk','Eggs','Bread','Internet','Taxi Travel','Electricity and Water']].astype('float').describe()
# Out:
#              Milk        Eggs       Bread    Internet  Taxi Travel  \
# count  160.000000  160.000000  160.000000  160.000000   160.000000
# mean     0.998937    1.902813    1.197875   29.660875     0.922250
# std      0.391720    0.752520    0.760670   18.908249     0.709011
# min      0.390000    0.750000    0.100000    4.440000     0.140000
# 25%      0.710000    1.377500    0.555000   12.832500     0.405000
# 50%      0.895000    1.850000    1.020000   26.615000     0.630000
# 75%      1.170000    2.352500    1.690000   43.317500     1.350000
# max      2.640000    5.330000    3.330000   93.290000     4.160000
#
#        Electricity and Water
# count             160.000000
# mean              107.106125
# std                51.553830
# min                18.560000
# 25%                63.860000
# 50%               102.465000
# 75%               145.707500
# max               265.520000

# %%
# Countries where Milk is expensive
print(x[x['Milk']>1.17][['Country','City','Milk']].sort_values(by='Milk',ascending = False).head().set_index('Country'))

print('\n')

# Countries where Eggs are expensive
print(x[x['Eggs']>2.35][['Country','City','Eggs']].sort_values(by='Eggs',ascending = False).head().set_index('Country'))

print('\n')

# Countries where Bread is expensive
print(x[x['Bread']>1.69][['Country','City','Bread']].sort_values(by='Bread',ascending = False).head().set_index('Country'))

print('\n')

# Countries where Internet is expensive
print(x[x['Internet']>43.31][['Country','City','Internet']].sort_values(by='Internet',ascending = False).head().set_index('Country'))

print('\n')

# Countries where Taxi is expensive
print(x[x['Taxi Travel']>1.35][['Country','City','Taxi Travel']].sort_values(by='Taxi Travel',ascending = False).head().set_index('Country'))

print('\n')

# Countries where Electricity and Water are expensive
print(x[x['Electricity and Water']>145.7][['Country','City','Electricity and Water']].sort_values(by='Electricity and Water',ascending = False).head().set_index('Country'))
# Out:
#                   City  Milk
# Country
# Taiwan          Taipei  2.64
# Hong Kong    Hong Kong  2.54
# China         Shanghai  2.39
# Singapore    Singapore  2.04
# South Korea      Seoul  1.95
#
#
#                   City  Eggs
# Country
# Switzerland     Zurich  5.33
# Iceland      Reykjavik   4.8
# Norway            Oslo  3.79
# France           Paris   3.4
# Israel       Jerusalem  3.32
#
#
#                   City Bread
# Country
# NY            New York  3.33
# CA           San Diego  3.27
# CA       San Francisco  3.12
# CA         Los Angeles  2.99
# Norway            Oslo  2.92
#
#
#                            City Internet
# Country
# United Arab Emirates  Abu Dhabi    93.29
# United Arab Emirates      Dubai    90.42
# Qatar                      Doha    78.31
# AZ                      Phoenix    67.23
# Costa Rica             San Jose     65.3
#
#
#                              City Taxi Travel
# Country
# Switzerland                Zurich        4.16
# Japan                       Tokyo        3.44
# Netherlands             Eindhoven           3
# United Kingdom             London        2.97
# Dominican Republic  Santo Domingo        2.55
#
#
#                City Electricity and Water
# Country
# Germany   Frankfurt                265.52
# Germany      Munich                242.66
# Germany     Hamburg                232.62
# Germany      Berlin                 231.8
# Slovenia  Ljubljana                199.61

# %%
# Recommending Better Cities to Live
def recommend_better_cities(citi, factor = 'Lifestyle'):
    x = city[['City','Food','Education','Lifestyle','Travel', 'Income']]
    food = x[x['City'] == citi]['Food']
    education = x[x['City'] == citi]['Education']
    lifestyle = x[x['City'] == citi]['Lifestyle']
    travel = x[x['City'] == citi]['Travel']
    income = x[x['City'] == citi]['Income']
    best_cities = x[(x['Food']<=food.values[0])&(x['Education']<=education.values[0])&
                    (x['Lifestyle']<=lifestyle.values[0])&(x['Travel']<=travel.values[0])&
                    (x['Income']>income.values[0])]
    best = best_cities.sort_values(by = factor, ascending = False).head(10)
    return best['City'].reset_index(drop=True)

# %%
recommend_better_cities('Sydney')
# Out:
# 0     Brisbane
# 1    Las Vegas
# Name: City, dtype: object
